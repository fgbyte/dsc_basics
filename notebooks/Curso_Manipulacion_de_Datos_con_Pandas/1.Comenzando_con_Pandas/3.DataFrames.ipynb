# %% [markdown]
# # ***Pan***el ***Da***ta
#
# PANDAS: Significa Paneles de Datos
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## DataFrame
# No es mas que una estructura bi dimensional en donde las columnas tienen varias categorías de datos.

# %% [markdown]
# Estas categorías pueden ser de diferentes types

# %%
import pandas as pd

pd.__version__  # validar la version de pandas q estamos usando
# Out:
# '2.2.3'

# %%
dict_data = {'CH': [100, 800, 200], 'CO': [
    100, 200, 300], 'MX': [300, 500, 400]}

dict_data
# Out:
# {'CH': [100, 800, 200], 'CO': [100, 200, 300], 'MX': [300, 500, 400]}

# %%
# transformar el diccionario en un dataframe

df = pd.DataFrame(dict_data)
df
# Out:
#     CH   CO   MX
# 0  100  100  300
# 1  800  200  500
# 2  200  300  400
